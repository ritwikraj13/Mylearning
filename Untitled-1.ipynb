# %%
total_amount = int(input("Enter the On Road Price of the Vehicle :  "))

down_payment = int(input("Enter Down payment amount :  "))

rate = 9.3/100

time = int(input("Enter Tenure in Months :  "))

#emi = ( total_amount * rate * (1+rate) ** time ) / ( (1+rate) ** time - 1 )

emi = total_amount * rate * ( 1+ rate ) * time / ((1+rate) * time - 1)

formatted_emi = "{:.2f}".format(emi)

print("The Monthly emi of your vehicle is :  " , formatted_emi ,)
# Out:
# The Monthly emi of your vehicle is :   10067.58

# %%
num1 = int(input("Enter number :  "))
num2 = int(input("Enter number :  "))
num3 = int(input("Enter number :  "))
num4 = int(input("Enter number :  "))

if(num1>num2):
    f1 = num1
else:
    f1 = num2
    
if (num3>num4):
    f2 = num3
else:
    f2 = num4
    
if(f1>f2):
    print(str(f1), " is greatest")
else:
    print(str(f2), " is greatest")
# Out:
# 4  is greatest

# %%
for i in range(1,100):
    while i%5==0:
        i = i+1
        print("Y" + str(i))
# Out:
# Y6
# Y11
# Y16
# Y21
# Y26
# Y31
# Y36
# Y41
# Y46
# Y51
# Y56
# Y61
# Y66
# Y71
# Y76
# Y81
# Y86
# Y91
# Y96

# %%
list = ['apple' , 'banana' , 'mangoes']

i =0

while i<len(list):
    print("A" + str(i))
    i = i+1
# Out:
# A0
# A1
# A2

# %%
for i in range(0,9):
    while i%3==0:  
        print('T' + str(i))
        i = i+1
# Out:
# T0
# T3
# T6

# %%
while i<100:
    for i in range(1,50):
        if i%7==0:
            print("T" + str(i))
            break
            i = i+1
# Out:
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# T7
# ...

# %%
num = int(input("Enter the number,u want factorial of :  "))

fact = 1
for i in range(1,num+1):
    fact = fact * i
    
print(fact)
# Out:
# 120

# %%
n = int(input("Enter any number :  "))

if n<=0:
    print(n ,"is not valid ,Try again, Enter a valid number")
    
elif n>0:
    if n%2==0:
        print("The entered number is even \nThank you!\nVisit again :)")
    else:
        print("The entered number is odd \nThank you! \nVisit again :)")
# Out:
# The entered number is odd
# Thank you!
# Visit again :)

# %%
s = input("Enter a string")

print(len(s))
# Out:
# 39

# %%
comment = input("Enter text :   ")

spam = False

if("buy now" in comment):
    spam = True
else :
    spam = False
    
if spam == True:
    print("This is a spam")
else:
    print("This is a ham")
# Out:
# This is a ham

# %%
list = ["apple" , "banana", "mango"]

n = input("Enter the keyword to search")


if n in list:
    print("present")
else:
    print("not present")
# Out:
# not present

# %%
username = input('Enter username :  ')

if len(username)==10:
    pwd = input("Enter password :  ")
    print("Congrats! , You are logged In")
    print(len(username))
    
else:
    print("username is not valid , Try again")
# Out:
# username is not valid , Try again

# %%
marks = int(input('Enter marks :  '))

if marks >= 90:
    print("A")
elif marks < 90 & marks>50:
    print("B")
elif marks <= 40:
    print("C")
else:
    print("F")
# Out:
# C

# %%
n = 4
for i in range(4):
    print(" " * (n-i-1), end =" ")
    print("*" * (2*i+1), end =" ")
    print(" " * (n-i-1))
# Out:
#     *
#    ***
#   *****
#  *******

# %%
for i in range(5):
    print("*" *(n-i))
# Out:
# *****
# ****
# ***
# **
# *

# %%
n = 5
for i in range(5):
    print("Ritwik" *(n-i))
# Out:
# RitwikRitwikRitwikRitwikRitwik
# RitwikRitwikRitwikRitwik
# RitwikRitwikRitwik
# RitwikRitwik
# Ritwik

# %%
print('''***
* *
***
      ''')
# Out:
# ***
# * *
# ***

# %%
n = 3

for i in range(3):
    print("*" * n)
    print(" " * (n-i-1) )
# Out:
# ***
# ***
# ***

# %%
num = int(input("Enter any number"))

for i in range(1,21):
    print(str(num) , "X", str(i) , "=" , str(num*i))
# Out:
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50
# 5 X 11 = 55
# 5 X 12 = 60
# 5 X 13 = 65
# 5 X 14 = 70
# 5 X 15 = 75
# 5 X 16 = 80
# 5 X 17 = 85
# 5 X 18 = 90
# 5 X 19 = 95
# 5 X 20 = 100

# %%
n = int(input("Enter number upto which u want to find factorial of "))

print("The entered number is" , n)
fact = 1
for i in range(1,n+1):
    fact = fact*i
    
    print(fact)
# Out:
# The entered number is 4
# 1
# 2
# 6
# 24

# %%
list = ["ritwik","sohan","sachin"]

for name in list:
    if name.startswith("s"):
        print("Hello " + name)
# Out:
# Hello sohan
# Hello sachin

# %%
num = int(input("Enter any number"))
prime = True

for i in range(2,num):
    if num % i == 0:
        prime = False
        break
        
if prime:
        print("The entered number is prime")
else:
    print("The entered number is not prime")
# Out:
# The entered number is not prime

# %%
def greet(name):
    print("Hello ", name)
    
greet('Ritwik')
# Out:
# Hello  Ritwik

# %%
def sum(n1,n2):
    return n1+n2

sum(2,3)
# Out:
# 5

# %%
def even_odd(n):
    if n % 2 == 0:
        print("even")
    else:
        print("odd")
    return even_odd

even_odd(5)
# Out:
# odd
# <function __main__.even_odd(n)>

# %%
def maximum(n1,n2,n3):
    if n1>n2:
        m1 = n1
    else:
        m1 = n2
    
    if m1>n3:
        print(str(m1),"is greatest")    
    else:
        print(str(n3),"is greatest")
    
maximum(5,2,3)
# Out:
# 5 is greatest
